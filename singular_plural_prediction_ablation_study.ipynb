# %%
import torch
import numpy
import pandas as pd
import os
import random
import transformer_lens.utils as utils
from transformer_lens import ActivationCache, HookedTransformer
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F

# %%
model = HookedTransformer.from_pretrained(
    "gpt2-XL",
    center_unembed=True,
    center_writing_weights=True,
    fold_ln=True,
    refactor_factored_attn_matrices=True
)
# Out:
# Loaded pretrained model gpt2-XL into HookedTransformer

# %%
model
# Out:
# HookedTransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (pos_embed): PosEmbed()
#   (hook_pos_embed): HookPoint()
#   (blocks): ModuleList(
#     (0-47): 48 x TransformerBlock(
#       (ln1): LayerNormPre(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (ln2): LayerNormPre(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (attn): Attention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#       )
#       (mlp): MLP(
#         (hook_pre): HookPoint()
#         (hook_post): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_mid): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (ln_final): LayerNormPre(
#     (hook_scale): HookPoint()
#     (hook_normalized): HookPoint()
#   )
#   (unembed): Unembed()
# )

# %%
data_path = '../dataset_csvs_singular_plural/s_plurals.csv'

# %%
data = pd.read_csv(data_path)
data.shape, data.columns
# Out:
# ((127, 2), Index(['sentence', 'answer'], dtype='object'))

# %%
average_attention_weights = np.load('../nouns_average_weights_sing_to_plu.npy')

# %%
average_attention_weights.shape
# Out:
# (48, 25, 64)

# %%
layers = 48
heads = 25
dim = 64

# %%
# Convert average_attention_weights to a PyTorch tensor if it's not already
average_attention_weights = torch.tensor(average_attention_weights)

def replace_hook_z(z, hook):
    layer_num = int(hook.name.split('.')[1])
    # The 4th column is index 4 because of the prepended BOS token
    z[:, 4, head, :] = average_attention_weights[layer_num, head, :].to(z.device)
    return z

for target_layer in range(0, layers):
    for head in range(0, heads):
        print(f"Processing layer {target_layer}, head {head}")
        results = []
        for idx, row in data.iterrows():
            singular = row['sentence']
            plural = row['answer']
            
            # Run the forward pass with the hook
            with model.hooks(fwd_hooks=[
                (f'blocks.{target_layer}.attn.hook_z', lambda z, hook, h=head: replace_hook_z(z, hook))
            ]):
                logits = model(singular, prepend_bos=True, return_type="logits")
            
            # Get the prediction and probability
            probs = F.softmax(logits[0, -1], dim=-1)
            pred_id = probs.argmax().item()
            prediction = model.to_string(pred_id)
            probability = probs[pred_id].item()
            
            # Store the results
            results.append({
                'singular': singular,
                'plural': plural,
                'prediction': prediction,
                'probability': probability
            })

        # Convert results to a DataFrame
        results_df = pd.DataFrame(results)
        results_df.to_csv('../mean_ablated_predictions/predictions_s_plural_XL_layer_' + str(target_layer) + '_' + str(head) +  '.csv')
# Out:
# /var/folders/d5/69sv554d0vsbs9pgt_yq5v0h0000gn/T/ipykernel_8197/3961935243.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   average_attention_weights = torch.tensor(average_attention_weights)
# Processing layer 0, head 0
# Processing layer 0, head 1
# Processing layer 0, head 2
# Processing layer 0, head 3
# Processing layer 0, head 4
# Processing layer 0, head 5
# Processing layer 0, head 6
# Processing layer 0, head 7
# Processing layer 0, head 8
# Processing layer 0, head 9
# Processing layer 0, head 10
# Processing layer 0, head 11
# Processing layer 0, head 12
# Processing layer 0, head 13
# Processing layer 0, head 14
# Processing layer 0, head 15
# Processing layer 0, head 16
# Processing layer 0, head 17
# Processing layer 0, head 18
# Processing layer 0, head 19
# Processing layer 0, head 20
# Processing layer 0, head 21
# Processing layer 0, head 22
# Processing layer 0, head 23
# Processing layer 0, head 24
# Processing layer 1, head 0
# Processing layer 1, head 1
# Processing layer 1, head 2
# Processing layer 1, head 3
# Processing layer 1, head 4
# Processing layer 1, head 5
# Processing layer 1, head 6
# Processing layer 1, head 7
# Processing layer 1, head 8
# Processing layer 1, head 9
# Processing layer 1, head 10
# Processing layer 1, head 11
# Processing layer 1, head 12
# Processing layer 1, head 13
# Processing layer 1, head 14
# Processing layer 1, head 15
# Processing layer 1, head 16
# Processing layer 1, head 17
# Processing layer 1, head 18
# Processing layer 1, head 19
# Processing layer 1, head 20
# Processing layer 1, head 21
# Processing layer 1, head 22
# Processing layer 1, head 23
# Processing layer 1, head 24
# Processing layer 2, head 0
# Processing layer 2, head 1
# Processing layer 2, head 2
# Processing layer 2, head 3
# Processing layer 2, head 4
# Processing layer 2, head 5
# Processing layer 2, head 6
# Processing layer 2, head 7
# Processing layer 2, head 8
# Processing layer 2, head 9
# Processing layer 2, head 10
# Processing layer 2, head 11
# Processing layer 2, head 12
# Processing layer 2, head 13
# Processing layer 2, head 14
# Processing layer 2, head 15
# Processing layer 2, head 16
# Processing layer 2, head 17
# Processing layer 2, head 18
# Processing layer 2, head 19
# Processing layer 2, head 20
# Processing layer 2, head 21
# Processing layer 2, head 22
# Processing layer 2, head 23
# Processing layer 2, head 24
# Processing layer 3, head 0
# Processing layer 3, head 1
# Processing layer 3, head 2
# Processing layer 3, head 3
# Processing layer 3, head 4
# Processing layer 3, head 5
# Processing layer 3, head 6
# Processing layer 3, head 7
# Processing layer 3, head 8
# Processing layer 3, head 9
# Processing layer 3, head 10
# Processing layer 3, head 11
# Processing layer 3, head 12
# Processing layer 3, head 13
# Processing layer 3, head 14
# Processing layer 3, head 15
# Processing layer 3, head 16
# Processing layer 3, head 17
# Processing layer 3, head 18
# Processing layer 3, head 19
# Processing layer 3, head 20
# Processing layer 3, head 21
# Processing layer 3, head 22
# Processing layer 3, head 23
# Processing layer 3, head 24
# Processing layer 4, head 0
# Processing layer 4, head 1
# Processing layer 4, head 2
# Processing layer 4, head 3
# Processing layer 4, head 4
# Processing layer 4, head 5
# Processing layer 4, head 6
# Processing layer 4, head 7
# Processing layer 4, head 8
# Processing layer 4, head 9
# Processing layer 4, head 10
# Processing layer 4, head 11
# Processing layer 4, head 12
# Processing layer 4, head 13
# Processing layer 4, head 14
# Processing layer 4, head 15
# Processing layer 4, head 16
# Processing layer 4, head 17
# Processing layer 4, head 18
# Processing layer 4, head 19
# Processing layer 4, head 20
# Processing layer 4, head 21
# Processing layer 4, head 22
# Processing layer 4, head 23
# Processing layer 4, head 24
# Processing layer 5, head 0
# Processing layer 5, head 1
# Processing layer 5, head 2
# Processing layer 5, head 3
# Processing layer 5, head 4
# Processing layer 5, head 5
# Processing layer 5, head 6
# Processing layer 5, head 7
# Processing layer 5, head 8
# Processing layer 5, head 9
# Processing layer 5, head 10
# Processing layer 5, head 11
# Processing layer 5, head 12
# Processing layer 5, head 13
# Processing layer 5, head 14
# Processing layer 5, head 15
# Processing layer 5, head 16
# Processing layer 5, head 17
# Processing layer 5, head 18
# Processing layer 5, head 19
# Processing layer 5, head 20
# Processing layer 5, head 21
# Processing layer 5, head 22
# Processing layer 5, head 23
# Processing layer 5, head 24
# Processing layer 6, head 0
# Processing layer 6, head 1
# Processing layer 6, head 2
# Processing layer 6, head 3
# Processing layer 6, head 4
# Processing layer 6, head 5
# Processing layer 6, head 6
# Processing layer 6, head 7
# Processing layer 6, head 8
# Processing layer 6, head 9
# Processing layer 6, head 10
# Processing layer 6, head 11
# Processing layer 6, head 12
# Processing layer 6, head 13
# Processing layer 6, head 14
# Processing layer 6, head 15
# Processing layer 6, head 16
# Processing layer 6, head 17
# Processing layer 6, head 18
# Processing layer 6, head 19
# Processing layer 6, head 20
# Processing layer 6, head 21
# Processing layer 6, head 22
# Processing layer 6, head 23
# Processing layer 6, head 24
# Processing layer 7, head 0
# Processing layer 7, head 1
# Processing layer 7, head 2
# Processing layer 7, head 3
# Processing layer 7, head 4
# Processing layer 7, head 5
# Processing layer 7, head 6
# Processing layer 7, head 7
# Processing layer 7, head 8
# Processing layer 7, head 9
# Processing layer 7, head 10
# Processing layer 7, head 11
# Processing layer 7, head 12
# Processing layer 7, head 13
# Processing layer 7, head 14
# Processing layer 7, head 15
# Processing layer 7, head 16
# Processing layer 7, head 17
# Processing layer 7, head 18
# Processing layer 7, head 19
# Processing layer 7, head 20
# Processing layer 7, head 21
# Processing layer 7, head 22
# Processing layer 7, head 23
# Processing layer 7, head 24
# Processing layer 8, head 0
# Processing layer 8, head 1
# Processing layer 8, head 2
# Processing layer 8, head 3
# Processing layer 8, head 4
# Processing layer 8, head 5
# Processing layer 8, head 6
# Processing layer 8, head 7
# Processing layer 8, head 8
# Processing layer 8, head 9
# Processing layer 8, head 10
# Processing layer 8, head 11
# Processing layer 8, head 12
# Processing layer 8, head 13
# Processing layer 8, head 14
# Processing layer 8, head 15
# Processing layer 8, head 16
# Processing layer 8, head 17
# Processing layer 8, head 18
# Processing layer 8, head 19
# Processing layer 8, head 20
# Processing layer 8, head 21
# Processing layer 8, head 22
# Processing layer 8, head 23
# Processing layer 8, head 24
# Processing layer 9, head 0
# Processing layer 9, head 1
# Processing layer 9, head 2
# Processing layer 9, head 3
# Processing layer 9, head 4
# Processing layer 9, head 5
# Processing layer 9, head 6
# Processing layer 9, head 7
# Processing layer 9, head 8
# Processing layer 9, head 9
# Processing layer 9, head 10
# Processing layer 9, head 11
# Processing layer 9, head 12
# Processing layer 9, head 13
# Processing layer 9, head 14
# Processing layer 9, head 15
# Processing layer 9, head 16
# Processing layer 9, head 17
# Processing layer 9, head 18
# Processing layer 9, head 19
# Processing layer 9, head 20
# Processing layer 9, head 21
# Processing layer 9, head 22
# Processing layer 9, head 23
# Processing layer 9, head 24
# Processing layer 10, head 0
# Processing layer 10, head 1
# Processing layer 10, head 2
# Processing layer 10, head 3
# Processing layer 10, head 4
# Processing layer 10, head 5
# Processing layer 10, head 6
# Processing layer 10, head 7
# Processing layer 10, head 8
# Processing layer 10, head 9
# Processing layer 10, head 10
# Processing layer 10, head 11
# Processing layer 10, head 12
# Processing layer 10, head 13
# Processing layer 10, head 14
# Processing layer 10, head 15
# Processing layer 10, head 16
# Processing layer 10, head 17
# Processing layer 10, head 18
# Processing layer 10, head 19
# Processing layer 10, head 20
# Processing layer 10, head 21
# Processing layer 10, head 22
# Processing layer 10, head 23
# Processing layer 10, head 24
# Processing layer 11, head 0
# Processing layer 11, head 1
# Processing layer 11, head 2
# Processing layer 11, head 3
# Processing layer 11, head 4
# Processing layer 11, head 5
# Processing layer 11, head 6
# Processing layer 11, head 7
# Processing layer 11, head 8
# Processing layer 11, head 9
# Processing layer 11, head 10
# Processing layer 11, head 11
# Processing layer 11, head 12
# Processing layer 11, head 13
# Processing layer 11, head 14
# Processing layer 11, head 15
# Processing layer 11, head 16
# Processing layer 11, head 17
# Processing layer 11, head 18
# Processing layer 11, head 19
# Processing layer 11, head 20
# Processing layer 11, head 21
# Processing layer 11, head 22
# Processing layer 11, head 23
# Processing layer 11, head 24
# Processing layer 12, head 0
# Processing layer 12, head 1
# Processing layer 12, head 2
# Processing layer 12, head 3
# Processing layer 12, head 4
# Processing layer 12, head 5
# Processing layer 12, head 6
# Processing layer 12, head 7
# Processing layer 12, head 8
# Processing layer 12, head 9
# Processing layer 12, head 10
# Processing layer 12, head 11
# Processing layer 12, head 12
# Processing layer 12, head 13
# Processing layer 12, head 14
# Processing layer 12, head 15
# Processing layer 12, head 16
# Processing layer 12, head 17
# Processing layer 12, head 18
# Processing layer 12, head 19
# Processing layer 12, head 20
# Processing layer 12, head 21
# Processing layer 12, head 22
# Processing layer 12, head 23
# Processing layer 12, head 24
# Processing layer 13, head 0
# Processing layer 13, head 1
# Processing layer 13, head 2
# Processing layer 13, head 3
# Processing layer 13, head 4
# Processing layer 13, head 5
# Processing layer 13, head 6
# Processing layer 13, head 7
# Processing layer 13, head 8
# Processing layer 13, head 9
# Processing layer 13, head 10
# Processing layer 13, head 11
# Processing layer 13, head 12
# Processing layer 13, head 13
# Processing layer 13, head 14
# Processing layer 13, head 15
# Processing layer 13, head 16
# Processing layer 13, head 17
# Processing layer 13, head 18
# Processing layer 13, head 19
# Processing layer 13, head 20
# Processing layer 13, head 21
# Processing layer 13, head 22
# Processing layer 13, head 23
# Processing layer 13, head 24
# Processing layer 14, head 0
# Processing layer 14, head 1
# Processing layer 14, head 2
# Processing layer 14, head 3
# Processing layer 14, head 4
# Processing layer 14, head 5
# Processing layer 14, head 6
# Processing layer 14, head 7
# Processing layer 14, head 8
# Processing layer 14, head 9
# Processing layer 14, head 10
# Processing layer 14, head 11
# Processing layer 14, head 12
# Processing layer 14, head 13
# Processing layer 14, head 14
# Processing layer 14, head 15
# Processing layer 14, head 16
# Processing layer 14, head 17
# Processing layer 14, head 18
# Processing layer 14, head 19
# Processing layer 14, head 20
# Processing layer 14, head 21
# Processing layer 14, head 22
# Processing layer 14, head 23
# Processing layer 14, head 24
# Processing layer 15, head 0
# Processing layer 15, head 1
# Processing layer 15, head 2
# Processing layer 15, head 3
# Processing layer 15, head 4
# Processing layer 15, head 5
# Processing layer 15, head 6
# Processing layer 15, head 7
# Processing layer 15, head 8
# Processing layer 15, head 9
# Processing layer 15, head 10
# Processing layer 15, head 11
# Processing layer 15, head 12
# Processing layer 15, head 13
# Processing layer 15, head 14
# Processing layer 15, head 15
# Processing layer 15, head 16
# Processing layer 15, head 17
# Processing layer 15, head 18
# Processing layer 15, head 19
# Processing layer 15, head 20
# Processing layer 15, head 21
# Processing layer 15, head 22
# Processing layer 15, head 23
# Processing layer 15, head 24
# Processing layer 16, head 0
# Processing layer 16, head 1
# Processing layer 16, head 2
# Processing layer 16, head 3
# Processing layer 16, head 4
# Processing layer 16, head 5
# Processing layer 16, head 6
# Processing layer 16, head 7
# Processing layer 16, head 8
# Processing layer 16, head 9
# Processing layer 16, head 10
# Processing layer 16, head 11
# Processing layer 16, head 12
# Processing layer 16, head 13
# Processing layer 16, head 14
# Processing layer 16, head 15
# Processing layer 16, head 16
# Processing layer 16, head 17
# Processing layer 16, head 18
# Processing layer 16, head 19
# Processing layer 16, head 20
# Processing layer 16, head 21
# Processing layer 16, head 22
# Processing layer 16, head 23
# Processing layer 16, head 24
# Processing layer 17, head 0
# Processing layer 17, head 1
# Processing layer 17, head 2
# Processing layer 17, head 3
# Processing layer 17, head 4
# Processing layer 17, head 5
# Processing layer 17, head 6
# Processing layer 17, head 7
# Processing layer 17, head 8
# Processing layer 17, head 9
# Processing layer 17, head 10
# Processing layer 17, head 11
# Processing layer 17, head 12
# Processing layer 17, head 13
# Processing layer 17, head 14
# Processing layer 17, head 15
# Processing layer 17, head 16
# Processing layer 17, head 17
# Processing layer 17, head 18
# Processing layer 17, head 19
# Processing layer 17, head 20
# Processing layer 17, head 21
# Processing layer 17, head 22
# Processing layer 17, head 23
# Processing layer 17, head 24
# Processing layer 18, head 0
# Processing layer 18, head 1
# Processing layer 18, head 2
# Processing layer 18, head 3
# Processing layer 18, head 4
# Processing layer 18, head 5
# Processing layer 18, head 6
# Processing layer 18, head 7
# Processing layer 18, head 8
# Processing layer 18, head 9
# Processing layer 18, head 10
# Processing layer 18, head 11
# Processing layer 18, head 12
# Processing layer 18, head 13
# Processing layer 18, head 14
# Processing layer 18, head 15
# Processing layer 18, head 16
# Processing layer 18, head 17
# Processing layer 18, head 18
# Processing layer 18, head 19
# Processing layer 18, head 20
# Processing layer 18, head 21
# Processing layer 18, head 22
# Processing layer 18, head 23
# Processing layer 18, head 24
# Processing layer 19, head 0
# Processing layer 19, head 1
# Processing layer 19, head 2
# Processing layer 19, head 3
# Processing layer 19, head 4
# Processing layer 19, head 5
# Processing layer 19, head 6
# Processing layer 19, head 7
# Processing layer 19, head 8
# Processing layer 19, head 9
# Processing layer 19, head 10
# Processing layer 19, head 11
# Processing layer 19, head 12
# Processing layer 19, head 13
# Processing layer 19, head 14
# Processing layer 19, head 15
# Processing layer 19, head 16
# Processing layer 19, head 17
# Processing layer 19, head 18
# Processing layer 19, head 19
# Processing layer 19, head 20
# Processing layer 19, head 21
# Processing layer 19, head 22
# Processing layer 19, head 23
# Processing layer 19, head 24
# Processing layer 20, head 0
# Processing layer 20, head 1
# Processing layer 20, head 2
# Processing layer 20, head 3
# Processing layer 20, head 4
# Processing layer 20, head 5
# Processing layer 20, head 6
# Processing layer 20, head 7
# Processing layer 20, head 8
# Processing layer 20, head 9
# Processing layer 20, head 10
# Processing layer 20, head 11
# Processing layer 20, head 12
# Processing layer 20, head 13
# Processing layer 20, head 14
# Processing layer 20, head 15
# Processing layer 20, head 16
# Processing layer 20, head 17
# Processing layer 20, head 18
# Processing layer 20, head 19
# Processing layer 20, head 20
# Processing layer 20, head 21
# Processing layer 20, head 22
# Processing layer 20, head 23
# Processing layer 20, head 24
# Processing layer 21, head 0
# Processing layer 21, head 1
# Processing layer 21, head 2
# Processing layer 21, head 3
# Processing layer 21, head 4
# Processing layer 21, head 5
# Processing layer 21, head 6
# Processing layer 21, head 7
# Processing layer 21, head 8
# Processing layer 21, head 9
# Processing layer 21, head 10
# Processing layer 21, head 11
# Processing layer 21, head 12
# Processing layer 21, head 13
# Processing layer 21, head 14
# Processing layer 21, head 15
# Processing layer 21, head 16
# Processing layer 21, head 17
# Processing layer 21, head 18
# Processing layer 21, head 19
# Processing layer 21, head 20
# Processing layer 21, head 21
# Processing layer 21, head 22
# Processing layer 21, head 23
# Processing layer 21, head 24
# Processing layer 22, head 0
# Processing layer 22, head 1
# Processing layer 22, head 2
# Processing layer 22, head 3
# Processing layer 22, head 4
# Processing layer 22, head 5
# Processing layer 22, head 6
# Processing layer 22, head 7
# Processing layer 22, head 8
# Processing layer 22, head 9
# Processing layer 22, head 10
# Processing layer 22, head 11
# Processing layer 22, head 12
# Processing layer 22, head 13
# Processing layer 22, head 14
# Processing layer 22, head 15
# Processing layer 22, head 16
# Processing layer 22, head 17
# Processing layer 22, head 18
# Processing layer 22, head 19
# Processing layer 22, head 20
# Processing layer 22, head 21
# Processing layer 22, head 22
# Processing layer 22, head 23
# Processing layer 22, head 24
# Processing layer 23, head 0
# Processing layer 23, head 1
# Processing layer 23, head 2
# Processing layer 23, head 3
# Processing layer 23, head 4
# Processing layer 23, head 5
# Processing layer 23, head 6
# Processing layer 23, head 7
# Processing layer 23, head 8
# Processing layer 23, head 9
# Processing layer 23, head 10
# Processing layer 23, head 11
# Processing layer 23, head 12
# Processing layer 23, head 13
# Processing layer 23, head 14
# Processing layer 23, head 15
# Processing layer 23, head 16
# Processing layer 23, head 17
# Processing layer 23, head 18
# Processing layer 23, head 19
# Processing layer 23, head 20
# Processing layer 23, head 21
# Processing layer 23, head 22
# Processing layer 23, head 23
# Processing layer 23, head 24
# Processing layer 24, head 0
# Processing layer 24, head 1
# Processing layer 24, head 2
# Processing layer 24, head 3
# Processing layer 24, head 4
# Processing layer 24, head 5
# Processing layer 24, head 6
# Processing layer 24, head 7
# Processing layer 24, head 8
# Processing layer 24, head 9
# Processing layer 24, head 10
# Processing layer 24, head 11
# Processing layer 24, head 12
# Processing layer 24, head 13
# Processing layer 24, head 14
# Processing layer 24, head 15
# Processing layer 24, head 16
# Processing layer 24, head 17
# Processing layer 24, head 18
# Processing layer 24, head 19
# Processing layer 24, head 20
# Processing layer 24, head 21
# Processing layer 24, head 22
# Processing layer 24, head 23
# Processing layer 24, head 24
# Processing layer 25, head 0
# Processing layer 25, head 1
# Processing layer 25, head 2
# Processing layer 25, head 3
# Processing layer 25, head 4
# Processing layer 25, head 5
# Processing layer 25, head 6
# Processing layer 25, head 7
# Processing layer 25, head 8
# Processing layer 25, head 9
# Processing layer 25, head 10
# Processing layer 25, head 11
# Processing layer 25, head 12
# Processing layer 25, head 13
# Processing layer 25, head 14
# Processing layer 25, head 15
# Processing layer 25, head 16
# Processing layer 25, head 17
# Processing layer 25, head 18
# Processing layer 25, head 19
# Processing layer 25, head 20
# Processing layer 25, head 21
# Processing layer 25, head 22
# Processing layer 25, head 23
# Processing layer 25, head 24
# Processing layer 26, head 0
# Processing layer 26, head 1
# Processing layer 26, head 2
# Processing layer 26, head 3
# Processing layer 26, head 4
# Processing layer 26, head 5
# Processing layer 26, head 6
# Processing layer 26, head 7
# Processing layer 26, head 8
# Processing layer 26, head 9
# Processing layer 26, head 10
# Processing layer 26, head 11
# Processing layer 26, head 12
# Processing layer 26, head 13
# Processing layer 26, head 14
# Processing layer 26, head 15
# Processing layer 26, head 16
# Processing layer 26, head 17
# Processing layer 26, head 18
# Processing layer 26, head 19
# Processing layer 26, head 20
# Processing layer 26, head 21
# Processing layer 26, head 22
# Processing layer 26, head 23
# Processing layer 26, head 24
# Processing layer 27, head 0
# Processing layer 27, head 1
# Processing layer 27, head 2
# Processing layer 27, head 3
# Processing layer 27, head 4
# Processing layer 27, head 5
# Processing layer 27, head 6
# Processing layer 27, head 7
# Processing layer 27, head 8
# Processing layer 27, head 9
# Processing layer 27, head 10
# Processing layer 27, head 11
# Processing layer 27, head 12
# Processing layer 27, head 13
# Processing layer 27, head 14
# Processing layer 27, head 15
# Processing layer 27, head 16
# Processing layer 27, head 17
# Processing layer 27, head 18
# Processing layer 27, head 19
# Processing layer 27, head 20
# Processing layer 27, head 21
# Processing layer 27, head 22
# Processing layer 27, head 23
# Processing layer 27, head 24
# Processing layer 28, head 0
# Processing layer 28, head 1
# Processing layer 28, head 2
# Processing layer 28, head 3
# Processing layer 28, head 4
# Processing layer 28, head 5
# Processing layer 28, head 6
# Processing layer 28, head 7
# Processing layer 28, head 8
# Processing layer 28, head 9
# Processing layer 28, head 10
# Processing layer 28, head 11
# Processing layer 28, head 12
# Processing layer 28, head 13
# Processing layer 28, head 14
# Processing layer 28, head 15
# Processing layer 28, head 16
# Processing layer 28, head 17
# Processing layer 28, head 18
# Processing layer 28, head 19
# Processing layer 28, head 20
# Processing layer 28, head 21
# Processing layer 28, head 22
# Processing layer 28, head 23
# Processing layer 28, head 24
# Processing layer 29, head 0
# Processing layer 29, head 1
# Processing layer 29, head 2
# Processing layer 29, head 3
# Processing layer 29, head 4
# Processing layer 29, head 5
# Processing layer 29, head 6
# Processing layer 29, head 7
# Processing layer 29, head 8
# Processing layer 29, head 9
# Processing layer 29, head 10
# Processing layer 29, head 11
# Processing layer 29, head 12
# Processing layer 29, head 13
# Processing layer 29, head 14
# Processing layer 29, head 15
# Processing layer 29, head 16
# Processing layer 29, head 17
# Processing layer 29, head 18
# Processing layer 29, head 19
# Processing layer 29, head 20
# Processing layer 29, head 21
# Processing layer 29, head 22
# Processing layer 29, head 23
# Processing layer 29, head 24
# Processing layer 30, head 0
# Processing layer 30, head 1
# Processing layer 30, head 2
# Processing layer 30, head 3
# Processing layer 30, head 4
# Processing layer 30, head 5
# Processing layer 30, head 6
# Processing layer 30, head 7
# Processing layer 30, head 8
# Processing layer 30, head 9
# Processing layer 30, head 10
# Processing layer 30, head 11
# Processing layer 30, head 12
# Processing layer 30, head 13
# Processing layer 30, head 14
# Processing layer 30, head 15
# Processing layer 30, head 16
# Processing layer 30, head 17
# Processing layer 30, head 18
# Processing layer 30, head 19
# Processing layer 30, head 20
# Processing layer 30, head 21
# Processing layer 30, head 22
# Processing layer 30, head 23
# Processing layer 30, head 24
# Processing layer 31, head 0
# Processing layer 31, head 1
# Processing layer 31, head 2
# Processing layer 31, head 3
# Processing layer 31, head 4
# Processing layer 31, head 5
# Processing layer 31, head 6
# Processing layer 31, head 7
# Processing layer 31, head 8
# Processing layer 31, head 9
# Processing layer 31, head 10
# Processing layer 31, head 11
# Processing layer 31, head 12
# Processing layer 31, head 13
# Processing layer 31, head 14
# Processing layer 31, head 15
# Processing layer 31, head 16
# Processing layer 31, head 17
# Processing layer 31, head 18
# Processing layer 31, head 19
# Processing layer 31, head 20
# Processing layer 31, head 21
# Processing layer 31, head 22
# Processing layer 31, head 23
# Processing layer 31, head 24
# Processing layer 32, head 0
# Processing layer 32, head 1
# Processing layer 32, head 2
# Processing layer 32, head 3
# Processing layer 32, head 4
# Processing layer 32, head 5
# Processing layer 32, head 6
# Processing layer 32, head 7
# Processing layer 32, head 8
# Processing layer 32, head 9
# Processing layer 32, head 10
# Processing layer 32, head 11
# Processing layer 32, head 12
# Processing layer 32, head 13
# Processing layer 32, head 14
# Processing layer 32, head 15
# Processing layer 32, head 16
# Processing layer 32, head 17
# Processing layer 32, head 18
# Processing layer 32, head 19
# Processing layer 32, head 20
# Processing layer 32, head 21
# Processing layer 32, head 22
# Processing layer 32, head 23
# Processing layer 32, head 24
# Processing layer 33, head 0
# Processing layer 33, head 1
# Processing layer 33, head 2
# Processing layer 33, head 3
# Processing layer 33, head 4
# Processing layer 33, head 5
# Processing layer 33, head 6
# Processing layer 33, head 7
# Processing layer 33, head 8
# Processing layer 33, head 9
# Processing layer 33, head 10
# Processing layer 33, head 11
# Processing layer 33, head 12
# Processing layer 33, head 13
# Processing layer 33, head 14
# Processing layer 33, head 15
# Processing layer 33, head 16
# Processing layer 33, head 17
# Processing layer 33, head 18
# Processing layer 33, head 19
# Processing layer 33, head 20
# Processing layer 33, head 21
# Processing layer 33, head 22
# Processing layer 33, head 23
# Processing layer 33, head 24
# Processing layer 34, head 0
# Processing layer 34, head 1
# Processing layer 34, head 2
# Processing layer 34, head 3
# Processing layer 34, head 4
# Processing layer 34, head 5
# Processing layer 34, head 6
# Processing layer 34, head 7
# Processing layer 34, head 8
# Processing layer 34, head 9
# Processing layer 34, head 10
# Processing layer 34, head 11
# Processing layer 34, head 12
# Processing layer 34, head 13
# Processing layer 34, head 14
# Processing layer 34, head 15
# Processing layer 34, head 16
# Processing layer 34, head 17
# Processing layer 34, head 18
# Processing layer 34, head 19
# Processing layer 34, head 20
# Processing layer 34, head 21
# Processing layer 34, head 22
# Processing layer 34, head 23
# Processing layer 34, head 24
# Processing layer 35, head 0
# Processing layer 35, head 1
# Processing layer 35, head 2
# Processing layer 35, head 3
# Processing layer 35, head 4
# Processing layer 35, head 5
# Processing layer 35, head 6
# Processing layer 35, head 7
# Processing layer 35, head 8
# Processing layer 35, head 9
# Processing layer 35, head 10
# Processing layer 35, head 11
# Processing layer 35, head 12
# Processing layer 35, head 13
# Processing layer 35, head 14
# Processing layer 35, head 15
# Processing layer 35, head 16
# Processing layer 35, head 17
# Processing layer 35, head 18
# Processing layer 35, head 19
# Processing layer 35, head 20
# Processing layer 35, head 21
# Processing layer 35, head 22
# Processing layer 35, head 23
# Processing layer 35, head 24
# Processing layer 36, head 0
# Processing layer 36, head 1
# Processing layer 36, head 2
# Processing layer 36, head 3
# Processing layer 36, head 4
# Processing layer 36, head 5
# Processing layer 36, head 6
# Processing layer 36, head 7
# Processing layer 36, head 8
# Processing layer 36, head 9
# Processing layer 36, head 10
# Processing layer 36, head 11
# Processing layer 36, head 12
# Processing layer 36, head 13
# Processing layer 36, head 14
# Processing layer 36, head 15
# Processing layer 36, head 16
# Processing layer 36, head 17
# Processing layer 36, head 18
# Processing layer 36, head 19
# Processing layer 36, head 20
# Processing layer 36, head 21
# Processing layer 36, head 22
# Processing layer 36, head 23
# Processing layer 36, head 24
# Processing layer 37, head 0
# Processing layer 37, head 1
# Processing layer 37, head 2
# Processing layer 37, head 3
# Processing layer 37, head 4
# Processing layer 37, head 5
# Processing layer 37, head 6
# Processing layer 37, head 7
# Processing layer 37, head 8
# Processing layer 37, head 9
# Processing layer 37, head 10
# Processing layer 37, head 11
# Processing layer 37, head 12
# Processing layer 37, head 13
# Processing layer 37, head 14
# Processing layer 37, head 15
# Processing layer 37, head 16
# Processing layer 37, head 17
# Processing layer 37, head 18
# Processing layer 37, head 19
# Processing layer 37, head 20
# Processing layer 37, head 21
# Processing layer 37, head 22
# Processing layer 37, head 23
# Processing layer 37, head 24
# Processing layer 38, head 0
# Processing layer 38, head 1
# Processing layer 38, head 2
# Processing layer 38, head 3
# Processing layer 38, head 4
# Processing layer 38, head 5
# Processing layer 38, head 6
# Processing layer 38, head 7
# Processing layer 38, head 8
# Processing layer 38, head 9
# Processing layer 38, head 10
# Processing layer 38, head 11
# Processing layer 38, head 12
# Processing layer 38, head 13
# Processing layer 38, head 14
# Processing layer 38, head 15
# Processing layer 38, head 16
# Processing layer 38, head 17
# Processing layer 38, head 18
# Processing layer 38, head 19
# Processing layer 38, head 20
# Processing layer 38, head 21
# Processing layer 38, head 22
# Processing layer 38, head 23
# Processing layer 38, head 24
# Processing layer 39, head 0
# Processing layer 39, head 1
# Processing layer 39, head 2
# Processing layer 39, head 3
# Processing layer 39, head 4
# Processing layer 39, head 5
# Processing layer 39, head 6
# Processing layer 39, head 7
# Processing layer 39, head 8
# Processing layer 39, head 9
# Processing layer 39, head 10
# Processing layer 39, head 11
# Processing layer 39, head 12
# Processing layer 39, head 13
# Processing layer 39, head 14
# Processing layer 39, head 15
# Processing layer 39, head 16
# Processing layer 39, head 17
# Processing layer 39, head 18
# Processing layer 39, head 19
# Processing layer 39, head 20
# Processing layer 39, head 21
# Processing layer 39, head 22
# Processing layer 39, head 23
# Processing layer 39, head 24
# Processing layer 40, head 0
# Processing layer 40, head 1
# Processing layer 40, head 2
# Processing layer 40, head 3
# Processing layer 40, head 4
# Processing layer 40, head 5
# Processing layer 40, head 6
# Processing layer 40, head 7
# Processing layer 40, head 8
# Processing layer 40, head 9
# Processing layer 40, head 10
# Processing layer 40, head 11
# Processing layer 40, head 12
# Processing layer 40, head 13
# Processing layer 40, head 14
# Processing layer 40, head 15
# Processing layer 40, head 16
# Processing layer 40, head 17
# Processing layer 40, head 18
# Processing layer 40, head 19
# Processing layer 40, head 20
# Processing layer 40, head 21
# Processing layer 40, head 22
# Processing layer 40, head 23
# Processing layer 40, head 24
# Processing layer 41, head 0
# Processing layer 41, head 1
# Processing layer 41, head 2
# Processing layer 41, head 3
# Processing layer 41, head 4
# Processing layer 41, head 5
# Processing layer 41, head 6
# Processing layer 41, head 7
# Processing layer 41, head 8
# Processing layer 41, head 9
# Processing layer 41, head 10
# Processing layer 41, head 11
# Processing layer 41, head 12
# Processing layer 41, head 13
# Processing layer 41, head 14
# Processing layer 41, head 15
# Processing layer 41, head 16
# Processing layer 41, head 17
# Processing layer 41, head 18
# Processing layer 41, head 19
# Processing layer 41, head 20
# Processing layer 41, head 21
# Processing layer 41, head 22
# Processing layer 41, head 23
# Processing layer 41, head 24
# Processing layer 42, head 0
# Processing layer 42, head 1
# Processing layer 42, head 2
# Processing layer 42, head 3
# Processing layer 42, head 4
# Processing layer 42, head 5
# Processing layer 42, head 6
# Processing layer 42, head 7
# Processing layer 42, head 8
# Processing layer 42, head 9
# Processing layer 42, head 10
# Processing layer 42, head 11
# Processing layer 42, head 12
# Processing layer 42, head 13
# Processing layer 42, head 14
# Processing layer 42, head 15
# Processing layer 42, head 16
# Processing layer 42, head 17
# Processing layer 42, head 18
# Processing layer 42, head 19
# Processing layer 42, head 20
# Processing layer 42, head 21
# Processing layer 42, head 22
# Processing layer 42, head 23
# Processing layer 42, head 24
# Processing layer 43, head 0
# Processing layer 43, head 1
# Processing layer 43, head 2
# Processing layer 43, head 3
# Processing layer 43, head 4
# Processing layer 43, head 5
# Processing layer 43, head 6
# Processing layer 43, head 7
# Processing layer 43, head 8
# Processing layer 43, head 9
# Processing layer 43, head 10
# Processing layer 43, head 11
# Processing layer 43, head 12
# Processing layer 43, head 13
# Processing layer 43, head 14
# Processing layer 43, head 15
# Processing layer 43, head 16
# Processing layer 43, head 17
# Processing layer 43, head 18
# Processing layer 43, head 19
# Processing layer 43, head 20
# Processing layer 43, head 21
# Processing layer 43, head 22
# Processing layer 43, head 23
# Processing layer 43, head 24
# Processing layer 44, head 0
# Processing layer 44, head 1
# Processing layer 44, head 2
# Processing layer 44, head 3
# Processing layer 44, head 4
# Processing layer 44, head 5
# Processing layer 44, head 6
# Processing layer 44, head 7
# Processing layer 44, head 8
# Processing layer 44, head 9
# Processing layer 44, head 10
# Processing layer 44, head 11
# Processing layer 44, head 12
# Processing layer 44, head 13
# Processing layer 44, head 14
# Processing layer 44, head 15
# Processing layer 44, head 16
# Processing layer 44, head 17
# Processing layer 44, head 18
# Processing layer 44, head 19
# Processing layer 44, head 20
# Processing layer 44, head 21
# Processing layer 44, head 22
# Processing layer 44, head 23
# Processing layer 44, head 24
# Processing layer 45, head 0
# Processing layer 45, head 1
# Processing layer 45, head 2
# Processing layer 45, head 3
# Processing layer 45, head 4
# Processing layer 45, head 5
# Processing layer 45, head 6
# Processing layer 45, head 7
# Processing layer 45, head 8
# Processing layer 45, head 9
# Processing layer 45, head 10
# Processing layer 45, head 11
# Processing layer 45, head 12
# Processing layer 45, head 13
# Processing layer 45, head 14
# Processing layer 45, head 15
# Processing layer 45, head 16
# Processing layer 45, head 17
# Processing layer 45, head 18
# Processing layer 45, head 19
# Processing layer 45, head 20
# Processing layer 45, head 21
# Processing layer 45, head 22
# Processing layer 45, head 23
# Processing layer 45, head 24
# Processing layer 46, head 0
# Processing layer 46, head 1
# Processing layer 46, head 2
# Processing layer 46, head 3
# Processing layer 46, head 4
# Processing layer 46, head 5
# Processing layer 46, head 6
# Processing layer 46, head 7
# Processing layer 46, head 8
# Processing layer 46, head 9
# Processing layer 46, head 10
# Processing layer 46, head 11
# Processing layer 46, head 12
# Processing layer 46, head 13
# Processing layer 46, head 14
# Processing layer 46, head 15
# Processing layer 46, head 16
# Processing layer 46, head 17
# Processing layer 46, head 18
# Processing layer 46, head 19
# Processing layer 46, head 20
# Processing layer 46, head 21
# Processing layer 46, head 22
# Processing layer 46, head 23
# Processing layer 46, head 24
# Processing layer 47, head 0
# Processing layer 47, head 1
# Processing layer 47, head 2
# Processing layer 47, head 3
# Processing layer 47, head 4
# Processing layer 47, head 5
# Processing layer 47, head 6
# Processing layer 47, head 7
# Processing layer 47, head 8
# Processing layer 47, head 9
# Processing layer 47, head 10
# Processing layer 47, head 11
# Processing layer 47, head 12
# Processing layer 47, head 13
# Processing layer 47, head 14
# Processing layer 47, head 15
# Processing layer 47, head 16
# Processing layer 47, head 17
# Processing layer 47, head 18
# Processing layer 47, head 19
# Processing layer 47, head 20
# Processing layer 47, head 21
# Processing layer 47, head 22
# Processing layer 47, head 23
# Processing layer 47, head 24

# %%
# Convert average_attention_weights to a PyTorch tensor if it's not already
average_attention_weights = torch.tensor(average_attention_weights)

def replace_hook_z(z, hook):
    layer_num = int(hook.name.split('.')[1])
    # The 4th column is index 4 because of the prepended BOS token
    z[:, 4, :, :] = average_attention_weights[layer_num, :, :].to(z.device)
    return z

for target_layer in range(0, layers):
    
    print(f"Processing layer {target_layer}")
    results = []
    for idx, row in data.iterrows():
        singular = row['sentence']
        plural = row['answer']
        
        # Run the forward pass with the hook
        with model.hooks(fwd_hooks=[
            (f'blocks.{target_layer}.attn.hook_z', lambda z, hook: replace_hook_z(z, hook))
        ]):
            logits = model(singular, prepend_bos=True, return_type="logits")
        
        # Get the prediction and probability
        probs = F.softmax(logits[0, -1], dim=-1)
        pred_id = probs.argmax().item()
        prediction = model.to_string(pred_id)
        probability = probs[pred_id].item()
        
        # Store the results
        results.append({
            'singular': singular,
            'plural': plural,
            'prediction': prediction,
            'probability': probability
        })

    # Convert results to a DataFrame
    results_df = pd.DataFrame(results)
    results_df.to_csv('../mean_ablated_predictions/predictions_s_plural_XL_layer_' + str(target_layer) +  '.csv')
# Out:
# /var/folders/d5/69sv554d0vsbs9pgt_yq5v0h0000gn/T/ipykernel_8197/978667374.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   average_attention_weights = torch.tensor(average_attention_weights)
# Processing layer 0
# Processing layer 1
# Processing layer 2
# Processing layer 3
# Processing layer 4
# Processing layer 5
# Processing layer 6
# Processing layer 7
# Processing layer 8
# Processing layer 9
# Processing layer 10
# Processing layer 11
# Processing layer 12
# Processing layer 13
# Processing layer 14
# Processing layer 15
# Processing layer 16
# Processing layer 17
# Processing layer 18
# Processing layer 19
# Processing layer 20
# Processing layer 21
# Processing layer 22
# Processing layer 23
# Processing layer 24
# Processing layer 25
# Processing layer 26
# Processing layer 27
# Processing layer 28
# Processing layer 29
# Processing layer 30
# Processing layer 31
# Processing layer 32
# Processing layer 33
# Processing layer 34
# Processing layer 35
# Processing layer 36
# Processing layer 37
# Processing layer 38
# Processing layer 39
# Processing layer 40
# Processing layer 41
# Processing layer 42
# Processing layer 43
# Processing layer 44
# Processing layer 45
# Processing layer 46
# Processing layer 47

# %%
count = 0
for i, row in results_df.iterrows():
    #print(row['plural'], row['prediction'][1:])
    if row['plural'] == row['prediction'][1:]:
        count += 1
count

# %%
# Out:
# -0.36473373
